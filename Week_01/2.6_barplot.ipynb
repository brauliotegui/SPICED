# %%
#Step 1: Load the file

import pandas as pd

df = pd.read_csv('/Users/braulio/Downloads/gapminder_total_fertility.csv', index_col=0)
df
# Out:
#                        1800  1801  1802  1803  1804  1805  1806  1807  1808  \
# Total fertility rate
# Abkhazia                NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Afghanistan            7.00  7.00  7.00  7.00  7.00  7.00  7.00  7.00  7.00
# Akrotiri and Dhekelia   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Albania                4.60  4.60  4.60  4.60  4.60  4.60  4.60  4.60  4.60
# Algeria                6.99  6.99  6.99  6.99  6.99  6.99  6.99  6.99  6.99
# ...                     ...   ...   ...   ...   ...   ...   ...   ...   ...
# Yugoslavia              NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Zambia                 6.71  6.71  6.71  6.71  6.71  6.71  6.71  6.71  6.71
# Zimbabwe               6.75  6.75  6.75  6.75  6.75  6.75  6.75  6.75  6.75
# Åland                   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Åland                   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
# ...

# %%
#Step 2: Select 3 years from the columns of the DataFrame e.g.:

df = df[['1950', '1975', '2000']]

# %%
#Step 3 Select 3 countries from the DataFrame index e.g.:

df = df.loc[['Germany', 'Brazil', 'Italy', 'Kenya']]
df
# Out:
#                       1950  1975  2000
# Total fertility rate
# Germany               2.07  1.56  1.35
# Brazil                6.18  4.50  2.36
# Italy                 2.45  2.17  1.22
# Kenya                 7.36  7.84  5.01

# %%
#Step 4: Draw a bar plot using the years as bar groups:

from matplotlib import pyplot as plt
df.plot.bar()

# %%
#Step 5: Modify the size of the diagram by adding figsize=(5,7) to the call of plot.bar.

df.plot.bar(figsize=(10,7))

# %%
#Step 6: Add another bar plot, this time selecting just one column:

df.plot.bar(y='1950', width=0.6, color='purple')

# %%
#Step 7: Transpose the DataFrame and see how the grouping of bars changes.

df.transpose().plot.bar()
